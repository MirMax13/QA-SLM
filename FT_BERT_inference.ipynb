# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch
import json
import evaluate
import numpy as np

# %%
# Завантажуємо токенізатор і модель
tokenizer = AutoTokenizer.from_pretrained("./bert_finetuned")
model = AutoModelForQuestionAnswering.from_pretrained("./bert_finetuned")

# %%
with open("samsung_refrigerator_qa.json", "r") as f:
    data = json.load(f)

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering", model="./bert_finetuned", tokenizer="./bert_finetuned")

generated_answers = []
true_answers = []
for item in data["data"]:
    for para in item["paragraphs"]:
        context = para["context"]
        for qa in para["qas"]:
            question = qa["question"]
            true_answer = qa["answers"][0]["text"] if qa["answers"] else "No answer"

            result = qa_pipeline(question=question, context=context)

            print(f"Question: {question}")
            print(f"Predicted answer: {result['answer']}")
            print(f"True answer: {true_answer}")
            print("-" * 30)
            generated_answers.append(result["answer"])
            true_answers.append(true_answer)
# Out:
# Device set to use cpu
# Question: Where should the appliance be installed?
# Predicted answer: Install the appliance on a firm and level floor
# True answer: on a firm and level floor
# ------------------------------
# Question: Where should the appliance not be installed?
# Predicted answer: Do not install the appliance in a damp and dusty place
# True answer: in a damp and dusty place
# ------------------------------
# Question: How do you activate Child Lock?
# Predicted answer: Lock, hold the Lock button for 5 seconds until the icon appears
# True answer: hold the Lock button for 5 seconds until the icon appears
# ------------------------------
# Question: How do you lock the control panel?
# Predicted answer: press the "Lock" button for 5 seconds until the padlock icon appears
# True answer: press the "Lock" button for 5 seconds until the padlock icon appears
# ------------------------------
# Question: Why should you lock the control panel?
# Predicted answer: panel
# True answer: This prevents accidental changes to settings
# ------------------------------
# Question: How often should the air filter be replaced?
# Predicted answer: The air filter should be replaced every 6 months
# True answer: every 6 months
# ------------------------------
# Question: How do you replace the air filter?
# Predicted answer: air filter should be replaced every 6 months
# True answer: open the top compartment and twist the filter counter-clockwise
# ------------------------------
# Question: How do you turn off the door alarm?
# Predicted answer: alarm, press and hold the Alarm button for 3 seconds
# True answer: press and hold the Alarm button for 3 seconds
# ------------------------------
# Question: When do the interior LED lights turn on?
# Predicted answer: The interior LED lights turn on automatically when the door is opened
# True answer: automatically when the door is opened
# ------------------------------
# Question: What should you do if the interior lights don't turn on?
# Predicted answer: interior LED lights turn on automatically when the door is opened.
# True answer: check the door sensor or replace the bulb
# ------------------------------
# Question: How do you clean the water dispenser?
# Predicted answer: water dispenser, remove the tray and wipe all surfaces
# True answer: remove the tray and wipe all surfaces with a soft cloth and warm water
# ------------------------------
# Question: What should be avoided when cleaning the water dispenser?
# Predicted answer: Avoid using harsh chemicals
# True answer: using harsh chemicals
# ------------------------------
# Question: How do you connect the fridge to Wi-Fi?
# Predicted answer: fridge to Wi-Fi, press the Wi-Fi button for 3 seconds
# True answer: press the Wi-Fi button for 3 seconds
# ------------------------------
# Question: How do you run diagnostics on the fridge?
# Predicted answer: Run diagnostics by holding the Settings and Light buttons simultaneously for 5 seconds
# True answer: by holding the Settings and Light buttons simultaneously for 5 seconds
# ------------------------------
# Question: What type of refrigerant does this appliance contain?
# Predicted answer: isobutane
# True answer: isobutane (R-600a)
# ------------------------------
# Question: What precautions should be taken during installation and servicing?
# Predicted answer: care should be taken
# True answer: care should be taken to ensure that no parts of the refrigerating circuit are damaged
# ------------------------------
# Question: What devices should not be used to accelerate defrosting?
# Predicted answer: mechanical devices
# True answer: mechanical devices or any other means to accelerate the defrosting process
# ------------------------------
# Question: What types of objects should not be kept in the refrigerator?
# Predicted answer: volatile or flammable
# True answer: volatile or flammable objects or substances
# ------------------------------
# Question: How should inner fittings be positioned for efficient energy use?
# Predicted answer: supplied by manufacturer
# True answer: on the position supplied by manufacturer
# ------------------------------
# Question: Who should replace a damaged supply cord?
# Predicted answer: it must be replaced by the manufacturer, its service agent or similarly qualified persons
# True answer: the manufacturer, its service agent or similarly qualified persons
# ------------------------------
# Question: What should you do if the appliance shows signs of damage?
# Predicted answer: Never start up an appliance showing any signs of damage
# True answer: Never start up the appliance
# ------------------------------
# Question: Who should you consult if in doubt about appliance damage?
# Predicted answer: your dealer
# True answer: your dealer
# ------------------------------
# Question: What can cause a significant increase in temperature inside the appliance?
# Predicted answer: Opening the door for long periods
# True answer: Opening the door for long periods
# ------------------------------
# Question: Can electrical appliances be used inside the food storage compartments?
# Predicted answer: Do not use electrical appliances inside the food storage compartments
# True answer: only if they are of the type recommended by the manufacturer
# ------------------------------
# Question: What type of water supply should be used?
# Predicted answer: potable
# True answer: potable water supply only
# ------------------------------
# Question: How does the temperature of two star compartments compare to other freezer compartments?
# Predicted answer: two star symbol is slightly higher
# True answer: slightly higher
# ------------------------------
# Question: What is the recommended fridge temperature?
# Predicted answer: The recommended fridge temperature is 3 В°C
# True answer: 3 В°C
# ------------------------------
# Question: What is the recommended freezer temperature?
# Predicted answer: freezer temperature is -19 В°C
# True answer: -19 В°C
# ------------------------------
# Question: What should be used to clean the refrigeratorвЂ™s interior and exterior?
# Predicted answer: use a moistened, soft, lint-free cloth or paper towel
# True answer: a moistened, soft, lint-free cloth or paper towel
# ------------------------------
# Question: What substances should not be stored in this appliance?
# Predicted answer: explosive substances such as aerosol cans with a flammable propellant
# True answer: explosive substances such as aerosol cans with a flammable propellant
# ------------------------------
# Question: What should not be used to fill the water tank?
# Predicted answer: Do not fill the tank with tea, juice or sports drink
# True answer: tea, juice or sports drink
# ------------------------------
# Question: What should be kept clear of obstruction?
# Predicted answer: built-in structure
# True answer: ventilation openings, in the appliance enclosure or in the built-in structure
# ------------------------------
# Question: Why should packaging materials be kept away from children?
# Predicted answer: away from children
# True answer: The packaging materials can cause suffocation
# ------------------------------
# Question: Should the appliance be placed in direct sunlight?
# Predicted answer: Do not place the appliance in direct sunlight
# True answer: No
# ------------------------------
# Question: What should the appliance not be exposed to?
# Predicted answer: heat from heating appliances such as stoves or heaters
# True answer: heat from heating appliances such as stoves or heaters
# ------------------------------
# Question: Where must the power plug be plugged in?
# Predicted answer: The power plug must be plugged into an appropriate outlet socket that is installed
# True answer: into an appropriate outlet socket that is installed and grounded
# ------------------------------
# Question: Which chemicals should not be used for cleaning the refrigerator?
# Predicted answer: citric or salt mixtures
# True answer: benzene, thinner, vinegar, liquid bleach, baking soda, citric or salt mixtures
# ------------------------------
# Question: What should you do before cleaning the refrigerator?
# Predicted answer: Always unplug the refrigerator before cleaning
# True answer: unplug the refrigerator
# ------------------------------
# Question: Is it safe to hang from the appliance doors or shelves?
# Predicted answer: Do not hang from the appliance doors
# True answer: No, do not hang from the appliance doors, storage room, shelf or climb up into it
# ------------------------------
# Question: How should raw meat and fish be stored?
# Predicted answer: raw meat and fish in suitable containers in the refrigerator
# True answer: in suitable containers in the refrigerator
# ------------------------------
# Question: What should you do if the refrigerator is left empty for a long time?
# Predicted answer: leave the door open
# True answer: switch off, defrost, clean, dry, and leave the door open
# ------------------------------
# Question: Why should the door be kept closed as much as possible?
# Predicted answer: to maintain the temperature and freshness of food
# True answer: to maintain the temperature and freshness of food
# ------------------------------
# Question: How long should Power Freeze be activated before freezing food?
# Predicted answer: activate Power Freeze for at least 20 hours
# True answer: at least 20 hours
# ------------------------------
# Question: What should be done regularly for the ice maker bucket?
# Predicted answer: ice maker bucket should be emptied regularly to maintain ice quality
# True answer: emptied regularly to maintain ice quality
# ------------------------------
# Question: Who should replace LED lamps in the appliance?
# Predicted answer: contact a local service center
# True answer: local service center
# ------------------------------
# Question: What should be avoided on the door baskets?
# Predicted answer: Avoid storing excessive amounts of water bottles or containers
# True answer: excessive amounts of water bottles or containers
# ------------------------------
# Question: How should the appliance be connected to the power supply?
# Predicted answer: appliance should be connected to a dedicated power line which is separately fused
# True answer: connected to a dedicated power line which is separately fused
# ------------------------------
# Question: Is it allowed to modify or extend the power cable?
# Predicted answer: Do not modify or extend the power cable
# True answer: No
# ------------------------------
# Question: Why must the socket be easily accessible?
# Predicted answer: accessible so that the appliance can be quickly disconnected from the supply
# True answer: so that the appliance can be quickly disconnected from the supply in an emergency
# ------------------------------
# Question: What age group is allowed to load and unload refrigerating appliances?
# Predicted answer: Children aged from 3 to 8 years
# True answer: Children aged from 3 to 8 years
# ------------------------------
# Question: Can electrical appliances be used inside food storage compartments?
# Predicted answer: electrical appliances inside the food storage compartments unless recommended by the manufacturer
# True answer: only if recommended by the manufacturer
# ------------------------------
# Question: When may the product not operate properly?
# Predicted answer: not operate properly at temperatures outside of the specific range specified by the climate class
# True answer: at temperatures outside of the specific range specified by the climate class
# ------------------------------
# Question: What should be done regarding the refrigerant disposal?
# Predicted answer: refrigerant which requires special disposal procedures
# True answer: contact local authorities for environmentally safe disposal
# ------------------------------
# Question: How should the appliance door be opened or closed?
# Predicted answer: Do not open or close the appliance door with excessive force
# True answer: not with excessive force
# ------------------------------
# Question: What should be done if the appliance door hinge is damaged?
# Predicted answer: stop using the appliance and contact an authorized service centre
# True answer: stop using the appliance and contact an authorized service centre
# ------------------------------
# Question: Where must the power plug be plugged in?
# Predicted answer: The power plug must be plugged into an appropriate outlet socket that is installed
# True answer: into an appropriate outlet socket that is installed and grounded
# ------------------------------
# Question: What type of hose-sets should be used with the appliance?
# Predicted answer: new hose-sets supplied with the appliance
# True answer: new hose-sets supplied with the appliance
# ------------------------------
# Question: Where should the appliance not be placed?
# Predicted answer: appliance in areas subject to weathering conditions
# True answer: areas subject to weathering conditions such as direct sunlight, wind, rain, or temperatures below freezing
# ------------------------------
# Question: How should inner fittings be positioned for energy efficiency?
# Predicted answer: efficient use of energy
# True answer: in the positions supplied by the manufacturer
# ------------------------------
# Question: What should be done if the appliance is left empty for long periods?
# Predicted answer: If the refrigerating appliance is left empty for long periods
# True answer: switch off, defrost, clean, dry, and leave the door open
# ------------------------------
# Question: What should you avoid to reduce the risk of injury?
# Predicted answer: do not hang from appliance doors, shelves, or storage rooms
# True answer: do not hang from appliance doors, shelves, or storage rooms
# ------------------------------
# Question: What should not be placed in the freezer compartment?
# Predicted answer: glass containers, bottles, or cans containing carbonated drinks
# True answer: glass containers, bottles, or cans containing carbonated drinks
# ------------------------------

# %%
metric = evaluate.load("squad")

predictions = [{"id": str(i), "prediction_text": pred} for i, pred in enumerate(generated_answers)]
references = [{"id": str(i), "answers": {"text": [ref], "answer_start": [0]}} for i, ref in enumerate(true_answers)]

results = metric.compute(predictions=predictions, references=references)

print("Exact Match:", results["exact_match"])
print("F1 Score:", results["f1"])
# Out:
# Exact Match: 17.741935483870968
# F1 Score: 62.64272610721143

# %%
bertscore = evaluate.load("bertscore")

results_bert = bertscore.compute(predictions=generated_answers, references=true_answers, lang="en")
# Out:
# d:\Projects\LLM\venv\lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\nobla\.cache\huggingface\hub\models--roberta-large. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BERTScore BERT: {'precision': [0.9222825765609741, 0.8856914043426514, 0.9583338499069214, 1.0, 0.8743570446968079, 0.8290807604789734, 0.8511108160018921, 0.9547451734542847, 0.8781918287277222, 0.8762181997299194, 0.9328922629356384, 0.9406851530075073, 0.9171909093856812, 0.9365199208259583, 0.9803174734115601, 0.9320204257965088, 0.929271936416626, 0.9491510391235352, 0.9242998361587524, 0.9086482524871826, 0.8869919776916504, 0.9999999403953552, 0.9999999403953552, 0.867555558681488, 0.9092748165130615, 0.8228372931480408, 0.8768212795257568, 0.8969036340713501, 0.9823201894760132, 1.0, 0.8757304549217224, 0.9037310481071472, 0.8526987433433533, 0.7951646447181702, 1.0000001192092896, 0.8950529098510742, 0.9331247806549072, 0.9167859554290771, 0.9603961706161499, 0.9084415435791016, 0.8953339457511902, 1.0, 0.8886969089508057, 0.8800479769706726, 0.9030711054801941, 0.9272675514221191, 0.932884156703949, 0.7947285771369934, 0.9633402228355408, 0.9999999403953552, 0.8746047616004944, 0.9326415657997131,